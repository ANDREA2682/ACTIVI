# %%
#Importación de bibliotecas de trabajo

import os #directorios de trabajo
import numpy as np # Métodos numéricos y manipulación de array
import pandas as pd #Data frame 
import matplotlib.pyplot as plt # componente grafico

# %%
#Establecer directorio de trabajo (working directoy)
os.chdir('C:\\Users\\andre\\OneDrive\\Escritorio\\Inteligencia artificial\\UNIDAD 1')
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
os.listdir
# Out:
# <function nt.listdir(path=None)>

# %%
# Importar base de datos

forbes22 = pd.read_csv('Data set/Forbes 2000 2022.csv',encoding= 'latin-1',sep=';')

# %%
forbes22.head()
# Out:
#    Rank                                    Company        Country     Sales   \
# 0      1                        Berkshire Hathaway  United States  $276.09 B
# 1      2                                      ICBC          China  $208.13 B
# 2      3  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  $400.38 B
# 3      4                            JPMorgan Chase  United States  $124.54 B
# 4      5                   China Construction Bank          China  $202.07 B
#
#      Profits       Assets       Market
# 0    $89.8 B    $958.78 B    $741.48 B
# 1   $54.03 B  $5,518.51 B    $214.43 B
# 2  $105.36 B    $576.04 B  $2,292.08 B
# 3   $42.12 B  $3,954.69 B    $374.45 B
# 4   $46.89 B  $4,746.95 B    $181.32 B

# %%
# Para ver la FORMA del DF
forbes22.shape # (Fila,columna)
# Out:
# (2000, 7)

# %%
### Data cleaning 

# Qué variables tengo

forbes22.columns
# Out:
# Index(['Rank ', 'Company', 'Country', 'Sales ', 'Profits', 'Assets', 'Market'], dtype='object')

# %%
forbes22.head(n=10) # Top 10 de las empresas de Forbes 21
#forbes21.tail(n=9) #Las últimas 5
# Out:
#    Rank                                    Company        Country     Sales   \
# 0      1                        Berkshire Hathaway  United States  $276.09 B
# 1      2                                      ICBC          China  $208.13 B
# 2      3  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  $400.38 B
# 3      4                            JPMorgan Chase  United States  $124.54 B
# 4      5                   China Construction Bank          China  $202.07 B
# 5      6                                    Amazon  United States  $469.82 B
# 6      7                                     Apple  United States   $378.7 B
# 7      8                Agricultural Bank of China          China  $181.42 B
# 8      9                           Bank of America  United States   $96.83 B
# 9     10                              Toyota Motor          Japan  $281.75 B
#
#      Profits       Assets       Market
# 0    $89.8 B    $958.78 B    $741.48 B
# 1   $54.03 B  $5,518.51 B    $214.43 B
# 2  $105.36 B    $576.04 B  $2,292.08 B
# 3   $42.12 B  $3,954.69 B    $374.45 B
# 4   $46.89 B  $4,746.95 B    $181.32 B
# 5   $33.36 B    $420.55 B   $1,468.4 B
# 6  $100.56 B    $381.19 B  $2,640.32 B
# 7   $37.38 B  $4,561.05 B    $133.38 B
# 8      $31 B  $3,238.22 B     $303.1 B
# 9   $28.15 B    $552.46 B    $237.73 B

# %%
forbes22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     2000 non-null   int64
#  1   Company  2000 non-null   object
#  2   Country  2000 non-null   object
#  3   Sales    2000 non-null   object
#  4   Profits  2000 non-null   object
#  5   Assets   2000 non-null   object
#  6   Market   2000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 109.5+ KB

# %%
forbes22.isna().any()
# Out:
# Rank       False
# Company    False
# Country    False
# Sales      False
# Profits    False
# Assets     False
# Market     False
# dtype: bool

# %%
# Modifiquemos el formato de los datos (Coerción de datos)

forbes22 = forbes22.replace(',','',regex= True) # regex: expresión regular
forbes22.head()
# Out:
#    Rank                                    Company        Country     Sales   \
# 0      1                        Berkshire Hathaway  United States  $276.09 B
# 1      2                                      ICBC          China  $208.13 B
# 2      3  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  $400.38 B
# 3      4                            JPMorgan Chase  United States  $124.54 B
# 4      5                   China Construction Bank          China  $202.07 B
#
#      Profits      Assets      Market
# 0    $89.8 B   $958.78 B   $741.48 B
# 1   $54.03 B  $5518.51 B   $214.43 B
# 2  $105.36 B   $576.04 B  $2292.08 B
# 3   $42.12 B  $3954.69 B   $374.45 B
# 4   $46.89 B  $4746.95 B   $181.32 B

# %%
forbes22 = forbes22.replace('\$','',regex=True) #La expresión regular de $ es con \$
forbes22.head()
# Out:
#    Rank                                    Company        Country    Sales   \
# 0      1                        Berkshire Hathaway  United States  276.09 B
# 1      2                                      ICBC          China  208.13 B
# 2      3  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  400.38 B
# 3      4                            JPMorgan Chase  United States  124.54 B
# 4      5                   China Construction Bank          China  202.07 B
#
#     Profits     Assets     Market
# 0    89.8 B   958.78 B   741.48 B
# 1   54.03 B  5518.51 B   214.43 B
# 2  105.36 B   576.04 B  2292.08 B
# 3   42.12 B  3954.69 B   374.45 B
# 4   46.89 B  4746.95 B   181.32 B

# %%
# Acceder a filas y columnas
# Indexing and slicing

#Cómo acceder indicando filas con indexación
forbes22[:] #Coja todas las filas
forbes22[999:1010]
forbes22[1900:]
# Out:
#       Rank                                             Company        Country  \
# 1900   1899                                      Brown & Brown  United States
# 1901   1902                                Commerce Bancshares  United States
# 1902   1902                                        Gold Fields   South Africa
# 1903   1904                                           TMB Bank       Thailand
# 1904   1905                                 China Aviation Oil      Singapore
# ...     ...                                                ...            ...
# 1995   1995  Shenzhen Feima International Supply Chain Co. ...          China
# 1996   1997                                               NMDC          India
# 1997   1997                         Sichuan Changhong Electric          China
# 1998   1999                              Credit Bank of Moscow         Russia
# 1999   1999                                 Satellite Chemical          China
#
#        Sales   Profits   Assets   Market
# 1900   3.05 B    574 M   9.93 B  19.18 B
# 1901   1.42 B  514.3 M  34.99 B   8.66 B
# 1902    4.2 B  789.3 M   7.35 B  12.23 B
# 1903   2.47 B    333 M  53.81 B   3.64 B
# 1904  17.64 B   40.3 M   1.54 B    562 M
# ...       ...      ...      ...      ...
# 1995     37 M   1.41 B    166 M   1.14 B
# 1996   3.52 B   1.41 B   5.71 B    6.4 B
# 1997  15.72 B   53.1 M  12.11 B   1.96 B
# 1998   2.53 B  370.1 M  45.15 B   2.06 B
# 1999   4.41 B  931.3 M   7.64 B   9.52 B
#
# [100 rows x 7 columns]

# %%
# Función iloc: df.iloc[filas,columnas] por indices o int
forbes22.iloc[1,3] #fila 1, columna 3
forbes22.iloc[:5,[2,4,6]]
forbes22.iloc[:2,2:]
# Out:
#          Country    Sales   Profits     Assets    Market
# 0  United States  276.09 B   89.8 B   958.78 B  741.48 B
# 1          China  208.13 B  54.03 B  5518.51 B  214.43 B

# %%
#Tenemos un caracter extraño que no puede ser coercionado a float: '-'

forbes22.isin(['-']) # Método de Pandas
# Out:
#       Rank   Company  Country  Sales   Profits  Assets  Market
# 0     False    False    False   False    False   False   False
# 1     False    False    False   False    False   False   False
# 2     False    False    False   False    False   False   False
# 3     False    False    False   False    False   False   False
# 4     False    False    False   False    False   False   False
# ...     ...      ...      ...     ...      ...     ...     ...
# 1995  False    False    False   False    False   False   False
# 1996  False    False    False   False    False   False   False
# 1997  False    False    False   False    False   False   False
# 1998  False    False    False   False    False   False   False
# 1999  False    False    False   False    False   False   False
#
# [2000 rows x 7 columns]

# %%
forbes22.isin(['-']).any()
#forbes22.isin(['-']).any().any()
# Out:
# Rank       False
# Company    False
# Country    False
# Sales      False
# Profits    False
# Assets     False
# Market     False
# dtype: bool

# %%
forbes22.isin(['-']).any()
# Out:
# Rank       False
# Company    False
# Country    False
# Sales      False
# Profits    False
# Assets     False
# Market     False
# dtype: bool

# %%
forbes22.isna().any()
# Out:
# Rank       False
# Company    False
# Country    False
# Sales      False
# Profits    False
# Assets     False
# Market     False
# dtype: bool

# %%
# ¿Cuántos datos vacias hay?

forbes22.isna().sum()
# Out:
# Rank       0
# Company    0
# Country    0
# Sales      0
# Profits    0
# Assets     0
# Market     0
# dtype: int64

# %%
# ¿A qué porcentaje del total de mis datos corresponden las observaciones vacias?

100*forbes22.isna().sum().sum()/forbes22.shape[0] # Vacios sobre numero de registros

# Si los vacios representan menos del 1%, podemos proceder a eliminarlos
# Out:
# 0.0

# %%
forbes22.isna().sum()
# Out:
# Rank       0
# Company    0
# Country    0
# Sales      0
# Profits    0
# Assets     0
# Market     0
# dtype: int64

# %%
# Cuáles empresas son el top 5 del ranking de forbes 2000 2021

forbes22.head(n=5)['Company']
# Out:
# 0                          Berkshire Hathaway
# 1                                        ICBC
# 2    Saudi Arabian Oil Company (Saudi Aramco)
# 3                              JPMorgan Chase
# 4                     China Construction Bank
# Name: Company, dtype: object

# %%
suda = ['Argentina','Bolivia','Brazil','Chile','Colombia','Ecuador','Paraguay','Peru','Uruguay','Venezuela']

# %%
f_suda = forbes22[forbes22['Country'].isin(suda)]

# %%
EUROPE = ['Albania', 'Germany', 'Andorra', 'Armenia', 'Austria', 'Azerbaijan', 'Belgium', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Cyprus', 'Croatia']

# %%
f_europe = forbes22[forbes22['Country'].isin(EUROPE)]

# %%
f_europe['Country'].value_counts()
# Out:
# Country
# Germany    52
# Austria     9
# Belgium     7
# Name: count, dtype: int64

# %%
f_suda['Country'].value_counts()
# Out:
# Country
# Brazil       23
# Chile         6
# Colombia      3
# Peru          1
# Uruguay       1
# Argentina     1
# Name: count, dtype: int64

# %%
#pip install matplotlib
import matplotlib.pyplot as plt

# %%
# Bar plot
table_suda=f_suda['Country'].value_counts()
table_suda

plt.bar(table_suda.index,table_suda.values, color = 'purple', alpha = 0.9, edgecolor = 'white') #Crea el gráfico de barras
plt.title('Frecuencia de empresas sudamericanas')
plt.xlabel('Paises sudamericanos')
plt.ylabel('Frecuencia absoluta')
plt.grid(color = 'gray',alpha = 0.3, linestyle = 'solid')

plt.show() #Imprime el gráfico

# %%
table_europe = f_europe['Country'].value_counts()


plt.bar(table_europe.index,table_europe.values, color = 'orange', alpha = .9, edgecolor = 'white') #Crea el gráfico de barras
plt.title('Frecuencia de empresas sudamericanas')
plt.xlabel('Paises sudamericanos')
plt.ylabel('Frecuencia absoluta')
plt.grid(color = 'gray',alpha = 0.3, linestyle = 'solid')

plt.show() #Imprime el gráfico

# %%
# pie chart

plt.pie(table_suda.values,labels=table_suda.index)
plt.title('Segmento de empresas por paises')

plt.show()
