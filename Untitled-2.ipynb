# %%
import os #establecer directorios de trabajo
import numpy as np # Métodos numéricos y manipulación de array
import matplotlib.pyplot as plt #Data frame
import seaborn as sns; sns.set() #componente gráfico
import pandas as pd

# %%
os.chdir('C:\\Users\\andre\\OneDrive\\Escritorio\\Inteligencia artificial\\UNIDAD 1')
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\andre\OneDrive\Escritorio\Inteligencia artificial\UNIDAD 1
# ['1. Introduccion.ipynb', '2. Numpy.ipynb', '3. PandasForbes.ipynb', 'Actividad 1.docx', 'Actividad 1.pdf', 'Data set', 'Untitled-1.ipynb']

# %%
# Import and pre-visualization
df = pd.read_csv('Data set/Forbes_2000_2022.csv',encoding= 'latin-1',sep=';')
df.head()
# Out:
#    Rank                                   Company        Country     Sales  \
# 0     1                        Berkshire Hathaway  United States  $ 276,09
# 1     2                                      ICBC          China  $ 208,13
# 2     3  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  $ 400,38
# 3     4                            JPMorgan Chase  United States  $ 124,54
# 4     5                   China Construction Bank          China  $ 202,07
#
#     Profits      Assets Market_Value
# 0   $ 89,80    $ 958,78     $ 741,48
# 1   $ 54,03  $5,518,510     $ 214,43
# 2  $ 105,36    $ 576,04   $2,292,080
# 3   $ 42,12  $3,954,690     $ 374,45
# 4   $ 46,89  $4,746,950     $ 181,32

# %%
print(df.shape)
print(df.columns)
# Out:
# (2000, 7)
# Index(['Rank', 'Company', 'Country', 'Sales', 'Profits', 'Assets',
#        'Market_Value'],
#       dtype='object')

# %%
# Para ver la FORMA del DF
df.shape # (Fila,columna)
# Out:
# (2000, 7)

# %%
### Data cleaning 

# Qué variables tengo

df.columns
# Out:
# Index(['Rank', 'Company', 'Country', 'Sales', 'Profits', 'Assets',
#        'Market_Value'],
#       dtype='object')

# %%
#Cambiar nombre de variables
df.columns = ['Rank','Company','Country','Sales','Profits','Assets','Market_value']
df.columns
# Out:
# Index(['Rank', 'Company', 'Country', 'Sales', 'Profits', 'Assets',
#        'Market_value'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          2000 non-null   int64
#  1   Company       2000 non-null   object
#  2   Country       2000 non-null   object
#  3   Sales         2000 non-null   object
#  4   Profits       2000 non-null   object
#  5   Assets        2000 non-null   object
#  6   Market_value  2000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 109.5+ KB

# %%
df.describe()
# Out:
#               Rank
# count  2000.000000
# mean   1000.500000
# std     577.494589
# min       1.000000
# 25%     500.750000
# 50%    1000.500000
# 75%    1500.250000
# max    2000.000000

# %%
df=df.replace(',','',regex= True)
df.head()
# Out:
#    Rank                                   Company        Country    Sales  \
# 0     1                        Berkshire Hathaway  United States  $ 27609
# 1     2                                      ICBC          China  $ 20813
# 2     3  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  $ 40038
# 3     4                            JPMorgan Chase  United States  $ 12454
# 4     5                   China Construction Bank          China  $ 20207
#
#    Profits    Assets Market_value
# 0   $ 8980   $ 95878      $ 74148
# 1   $ 5403  $5518510      $ 21443
# 2  $ 10536   $ 57604     $2292080
# 3   $ 4212  $3954690      $ 37445
# 4   $ 4689  $4746950      $ 18132

# %%
df=df.replace('\$','',regex=True)

# %%
df = df.astype(str).apply(lambda x: x.str.replace('[^\w\s]',''))

# %%
import string
df= df.astype(str).apply(lambda x: x.str.replace('[{}]'.format(string.punctuation), ''))

# %%
df['Sales']=df['Sales'].astype(float)

# %%
df['Market_value']=df['Market_value'].astype(float)

# %%
df['Assets']=df['Assets'].astype(float)

# %%
df['Country'].value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.figure(figsize=(100,50))
plt.show()

# %%
df['Country'].value_counts().plot(kind='bar')
plt.title('Country segmentation')
plt.show()

# %%
df['Country'].value_counts()
# Out:
# Country
# United States           590
# China                   297
# Japan                   196
# South Korea              65
# United Kingdom           64
# Canada                   58
# India                    55
# France                   54
# Hong Kong                54
# Germany                  52
# Taiwan                   48
# Switzerland              40
# Sweden                   32
# Australia                30
# Italy                    26
# Russia                   24
# Netherlands              24
# Brazil                   23
# Spain                    21
# Ireland                  21
# Saudi Arabia             16
# Thailand                 14
# Israel                   13
# South Africa             13
# United Arab Emirates     13
# Denmark                  11
# Singapore                11
# Turkey                    9
# Austria                   9
# Finland                   9
# Luxembourg                9
# Mexico                    9
# Poland                    8
# Norway                    8
# Indonesia                 7
# Malaysia                  7
# Belgium                   7
# Chile                     6
# Qatar                     5
# Greece                    5
# Philippines               5
# Vietnam                   5
# Portugal                  4
# Colombia                  3
# Kuwait                    3
# Bermuda                   3
# Hungary                   2
# Morocco                   2
# Kazakhstan                2
# Cayman Islands            1
# Egypt                     1
# Argentina                 1
# Czech Republic            1
# Bahrain                   1
# Uruguay                   1
# Peru                      1
# Nigeria                   1
# Name: count, dtype: int64

# %%
# Análisis de ventas

x = df['Sales'].plot(kind='hist')
df.head()
plt.title('Sales histogram')
plt.show()

# %%
# Genre as dummy variable

df['Country'] = df['Country']
df['Country'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
# ventas y valor del mercado

plt.figure(figsize=(8, 6))
plt.title('Sales vs. Market_value')
plt.scatter(x= df['Sales'], y =  df['Market_value'], alpha=0.5, c='b', edgecolors='k')
plt.show()

# %%
# ventas y actvos

plt.figure(figsize=(8, 6))
plt.title('Sales vs. Assets')
plt.scatter(x= df['Sales'], y =  df['Assets'], alpha=0.5, c='b', edgecolors='k')
plt.show()
